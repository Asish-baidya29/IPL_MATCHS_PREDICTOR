# %%
import pandas as pd 
import numpy as np

# %%
match = pd.read_csv("matches.csv")
delivaeies = pd.read_csv("deliveries.csv")

# %%
match
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match.shape
# Out:
# (756, 18)

# %%
delivaeies
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
delivaeies.shape
# Out:
# (179078, 21)

# %%
delivaeies.groupby(["match_id","inning"]).sum()["total_runs"]
# Out:
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#                    ...
# 11413     2         170
# 11414     1         155
#           2         162
# 11415     1         152
#           2         157
# Name: total_runs, Length: 1528, dtype: int64

# %%
total_score_df = delivaeies.groupby(["match_id","inning"]).sum()["total_runs"].reset_index() #reset_index creat it as a datafream

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
total_score_df = total_score_df[total_score_df['inning']==1] #we need only 1st innings datas for predictions

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
match_df = match.merge(total_score_df[['match_id','total_runs']],left_on = 'id',right_on='match_id')

# %%
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df["team1"].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams = ['Sunrisers Hyderabad', 'Mumbai Indians','Royal Challengers Bangalore',
       'Kolkata Knight Riders', 'Kings XI Punjab',
       'Chennai Super Kings', 'Rajasthan Royals','Delhi Capitals']

# %%
match_df["team1"] = match_df["team1"].str.replace('Delhi Daredevils','Delhi Capitals')
match_df["team2"] = match_df["team2"].str.replace('Delhi Daredevils','Delhi Capitals')

match_df["team1"] = match_df["team1"].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df["team2"] = match_df["team2"].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df = match_df [match_df["team1"].isin (teams)]  
match_df = match_df [match_df["team1"].isin (teams)]
#only teams er moddhe jeje name a6e sudhu oii rows guloii rakho

# %%
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8  IPL-2017         Indore  10-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df = match_df[match_df ["dl_applied"] == 0]

# %%
match_df = match_df[['match_id','city','winner','total_runs']]

# %%
delivaey_df = match_df.merge(delivaeies,on="match_id")

# %%
delivaey_df=delivaey_df[delivaey_df["inning"]==2]

# %%
delivaey_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 162737     11415  Hyderabad       Mumbai Indians           152       2
# 162738     11415  Hyderabad       Mumbai Indians           152       2
# 162739     11415  Hyderabad       Mumbai Indians           152       2
# 162740     11415  Hyderabad       Mumbai Indians           152       2
# 162741     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivaey_df["total_runs_y"].isnull().sum()
# Out:
# 0

# %%
#delivaey_df["total_runs_y"] = pd.to_numeric(delivaey_df["total_runs_y"])
delivaey_df["current_score"] = delivaey_df.groupby("match_id")["total_runs_y"].cumsum()

# %%
delivaey_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 162737     11415  Hyderabad       Mumbai Indians           152       2
# 162738     11415  Hyderabad       Mumbai Indians           152       2
# 162739     11415  Hyderabad       Mumbai Indians           152       2
# 162740     11415  Hyderabad       Mumbai Indians           152       2
# 162741     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivaey_df["run_left"] = (delivaey_df["total_runs_x"]+1) - delivaey_df["current_score"]

# %%
delivaey_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 162737     11415  Hyderabad       Mumbai Indians           152       2
# 162738     11415  Hyderabad       Mumbai Indians           152       2
# 162739     11415  Hyderabad       Mumbai Indians           152       2
# 162740     11415  Hyderabad       Mumbai Indians           152       2
# 162741     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivaey_df["ball_left"] = 126 - ((delivaey_df["over"]*6) + delivaey_df["ball"])

# %%
delivaey_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 162737     11415  Hyderabad       Mumbai Indians           152       2
# 162738     11415  Hyderabad       Mumbai Indians           152       2
# 162739     11415  Hyderabad       Mumbai Indians           152       2
# 162740     11415  Hyderabad       Mumbai Indians           152       2
# 162741     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivaey_df["wicket"] = delivaey_df["player_dismissed"].fillna("0")
delivaey_df["wicket"] = delivaey_df["wicket"].apply(lambda x:x if x=="0" else "1")
delivaey_df["wicket"] = delivaey_df["wicket"].astype ("int")

delivaey_df["wicket"] = delivaey_df.groupby('match_id')["wicket"].cumsum().values
delivaey_df["wicket"] = 10 - delivaey_df["wicket"]
delivaey_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 162737     11415  Hyderabad       Mumbai Indians           152       2
# 162738     11415  Hyderabad       Mumbai Indians           152       2
# 162739     11415  Hyderabad       Mumbai Indians           152       2
# 162740     11415  Hyderabad       Mumbai Indians           152       2
# 162741     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# batting team ,bowling  team, city, runs_left , balls left, wickets left, total runs 1st inggis, crr , rrr, result

# %%
delivaey_df["CRR"] = (delivaey_df["current_score"]*6)/(120-delivaey_df["ball_left"])

# %%
delivaey_df["RRR"] = (delivaey_df["run_left"]*6)/delivaey_df["ball_left"]

# %%
predict_model_dataset = delivaey_df [["batting_team","bowling_team","city","run_left","ball_left","wicket","total_runs_x","CRR","RRR","winner"]]

# %%
predict_model_dataset
# Out:
#                        batting_team         bowling_team       city  run_left  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       207
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       207
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       207
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       205
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       201
# ...                             ...                  ...        ...       ...
# 162737          Chennai Super Kings       Mumbai Indians  Hyderabad         1
# 162738          Chennai Super Kings       Mumbai Indians  Hyderabad        -1
# 162739          Chennai Super Kings       Mumbai Indians  Hyderabad        -2
# 162740          Chennai Super Kings       Mumbai Indians  Hyderabad        -4
# 162741          Chennai Super Kings       Mumbai Indians  Hyderabad        -4
#
# ...

# %%
def result(row):
    if row["batting_team"] == row["winner"]: 
        return 1
    else: 
        return 0

# %%
predict_model_dataset["result"] = predict_model_dataset.apply(result,axis=1)
# Out:
# C:\Users\ASISH\AppData\Local\Temp\ipykernel_15928\1830071928.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predict_model_dataset["result"] = predict_model_dataset.apply(result,axis=1)

# %%
predict_model_dataset
# Out:
#                        batting_team         bowling_team       city  run_left  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       207
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       207
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       207
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       205
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       201
# ...                             ...                  ...        ...       ...
# 162737          Chennai Super Kings       Mumbai Indians  Hyderabad         1
# 162738          Chennai Super Kings       Mumbai Indians  Hyderabad        -1
# 162739          Chennai Super Kings       Mumbai Indians  Hyderabad        -2
# 162740          Chennai Super Kings       Mumbai Indians  Hyderabad        -4
# 162741          Chennai Super Kings       Mumbai Indians  Hyderabad        -4
#
# ...

# %%
predict_model_dataset = predict_model_dataset [["batting_team","bowling_team","city","run_left","ball_left","wicket","total_runs_x","CRR","RRR","result"]]

# %%
predict_model_dataset
# Out:
#                        batting_team         bowling_team       city  run_left  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       207
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       207
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       207
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       205
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       201
# ...                             ...                  ...        ...       ...
# 162737          Chennai Super Kings       Mumbai Indians  Hyderabad         1
# 162738          Chennai Super Kings       Mumbai Indians  Hyderabad        -1
# 162739          Chennai Super Kings       Mumbai Indians  Hyderabad        -2
# 162740          Chennai Super Kings       Mumbai Indians  Hyderabad        -4
# 162741          Chennai Super Kings       Mumbai Indians  Hyderabad        -4
#
# ...

# %%
#Shuffling all datas

final_df = predict_model_dataset.sample(predict_model_dataset.shape[0])

# %%
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            832
# run_left          0
# ball_left         0
# wicket            0
# total_runs_x      0
# CRR               0
# RRR               5
# result            0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df["ball_left"]!=0]

# %%
import seaborn as sns 
input_data = final_df.iloc[:,:-1]
output_data = final_df["result"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(input_data,output_data,test_size=0.2,random_state=42)

# %%
#from sklearn.preprocessing import LabelEncoder
#le = LabelEncoder()
#final_df["batting_team"] = le.fit_transform(final_df["batting_team"])
#final_df["bowling_team"] = le.fit_transform(final_df["bowling_team"])
#final_df["city"] = le.fit_transform(final_df["city"])

# %%
final_df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# run_left        0
# ball_left       0
# wicket          0
# total_runs_x    0
# CRR             0
# RRR             0
# result          0
# dtype: int64

# %%
#from sklearn.preprocessing import StandardScaler
#ss = StandardScaler()
#ss.fit(final_df[["batting_team","bowling_team","city","run_left","ball_left","wicket","CRR"]])
#ss.transform(final_df[["batting_team","bowling_team","city","run_left","ball_left","wicket","CRR"]])

# %%
#final_df[["batting_team1","bowling_team1","city1","run_left1","ball_left1","wicket1","CRR1"]] = pd.DataFrame(ss.transform(final_df[["batting_team","bowling_team","city","run_left","ball_left","wicket","CRR"]]))

# %%
final_df.describe()
# Out:
#            run_left     ball_left        wicket  total_runs_x           CRR  \
# count  77650.000000  77650.000000  77650.000000  77650.000000  77650.000000
# mean      93.546014     62.903902      7.534552    165.393767      7.430150
# std       49.939724     33.264836      2.127217     29.508471      2.276119
# min      -15.000000     -2.000000      0.000000     65.000000      0.000000
# 25%       54.000000     35.000000      6.000000    146.000000      6.238218
# 50%       93.000000     64.000000      8.000000    165.000000      7.459459
# 75%      131.000000     92.000000      9.000000    185.000000      8.684211
# max      264.000000    119.000000     10.000000    263.000000     42.000000
#
#                 RRR        result
# count  77650.000000  77650.000000
# mean      10.620228      0.516909
# std       14.337416      0.499717
# min     -516.000000      0.000000
# 25%        7.256146      0.000000
# 50%        9.000000      1.000000
# 75%       11.040000      1.000000
# ...

# %%
final_df
# Out:
#                        batting_team                 bowling_team        city  \
# 80084         Kolkata Knight Riders          Chennai Super Kings     Chennai
# 125633        Kolkata Knight Riders          Sunrisers Hyderabad   Hyderabad
# 156862        Kolkata Knight Riders  Royal Challengers Bangalore     Kolkata
# 141386             Delhi Daredevils          Chennai Super Kings        Pune
# 72565              Delhi Daredevils             Rajasthan Royals      Jaipur
# ...                             ...                          ...         ...
# 144767  Royal Challengers Bangalore             Delhi Daredevils       Delhi
# 108913             Rajasthan Royals              Kings XI Punjab  Chandigarh
# 86081              Delhi Daredevils               Mumbai Indians       Delhi
# 138668  Royal Challengers Bangalore             Delhi Daredevils   Bengaluru
# 78351              Delhi Daredevils              Kings XI Punjab  Dharamsala
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
pipe.score(x_test,y_test)
# Out:
# 0.8063103670315518

# %%
pipe.predict_proba(x_test)[10]
# Out:
# array([0.00665918, 0.99334082])

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','run_left','ball_left','wicket','total_runs_x','CRR','RRR']].dropna()
    temp_df = temp_df[temp_df['ball_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['run_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wicket'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivaey_df,74,pipe)
temp_df
# Out:
# Target- 178
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 13265            1                3                0  55.1  44.9
# 13273            2                8                0  49.5  50.5
# 13279            3                1                0  56.6  43.4
# 13285            4                7                1  68.8  31.2
# 13291            5               12                0  58.1  41.9
# 13297            6               13                0  45.2  54.8
# 13303            7                9                0  39.1  60.9
# 13311            8               15                0  25.1  74.9
# 13317            9                7                0  23.0  77.0
# 13324           10               17                0  12.0  88.0
# 13330           11                9                1  17.0  83.0
# 13336           12                9                0  13.8  86.2
# 13342           13                8                0  11.7  88.3
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-178')

# %%
final_df["batting_team"].unique()
# Out:
# array(['Kolkata Knight Riders', 'Delhi Daredevils', 'Mumbai Indians',
#        'Rajasthan Royals', 'Kings XI Punjab', 'Chennai Super Kings',
#        'Gujarat Lions', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Royal Challengers Bangalore', 'Pune Warriors',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiant',
#        'Rising Pune Supergiants', 'Delhi Capitals'], dtype=object)

# %%
final_df["city"].unique()
# Out:
# array(['Chennai', 'Hyderabad', 'Kolkata', 'Pune', 'Jaipur', 'Abu Dhabi',
#        'Chandigarh', 'Delhi', 'Mumbai', 'Sharjah', 'Mohali', 'Bangalore',
#        'Johannesburg', 'Kanpur', 'Dharamsala', 'Raipur', 'Bengaluru',
#        'Durban', 'Visakhapatnam', 'Port Elizabeth', 'Cape Town', 'Ranchi',
#        'Bloemfontein', 'Nagpur', 'Centurion', 'East London', 'Ahmedabad',
#        'Rajkot', 'Kochi', 'Cuttack', 'Kimberley', 'Indore'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals']

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62120 entries, 139243 to 24152
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   batting_team  62120 non-null  object
#  1   bowling_team  62120 non-null  object
#  2   city          62120 non-null  object
#  3   run_left      62120 non-null  int64
#  4   ball_left     62120 non-null  int64
#  5   wicket        62120 non-null  int32
#  6   total_runs_x  62120 non-null  int64
#  7   CRR           62120 non-null  float64
#  8   RRR           62120 non-null  float64
# dtypes: float64(2), int32(1), int64(3), object(3)
# memory usage: 4.5+ MB
